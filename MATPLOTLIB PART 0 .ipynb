# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib.inline
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
x = np.linspace(0,10,100)
fig =plt.figure()

# %%
plt.plot(x,np.sin(x),'*')
plt.plot(x,np.cos(x),'--')

plt.axis('equal')
fig.savefig('C://Users/Madhu/Desktop/Datasetsfig.png')

# %%
from PIL import Image
img =Image.open('Datasetsfig.png')
img.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-4695c5b8bbfe> in <module>
#       1 from PIL import Image
# ----> 2 img =Image.open('Datasetsfig.png')
#       3 img.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2764
#    2765     if filename:
# -> 2766         fp = builtins.open(filename, "rb")
#    2767         exclusive_fp = True
#    2768
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Datasetsfig.png'

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'ps': 'Postscript',
#  'eps': 'Encapsulated Postscript',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %%
fig ,ax=plt.subplots(2)
ax[0].plot(x,np.sin(x),'*')
ax[1].plot(x,np.cos(x),'--')

# %%
plt.plot(x, np.sin(x - 0), color='blue') # specify color by name
plt.plot(x, np.sin(x - 1), color='g') # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75') # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44') # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 and 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported
plt.title('controlling the color of plot elements')
# Out:
# Text(0.5, 1.0, 'controlling the color of plot elements')

# %%
plt.plot(x, x+1 , linestyle = 'solid')
plt.plot(x, x+2 , linestyle = 'dashed')
plt.plot(x, x + 3, linestyle='dashdot')
plt.plot(x, x + 4, linestyle='dotted');

# %%
plt.plot(x, np.sin(x))
plt.title('sin graph')
plt.xlabel('x')
plt.ylabel('sin x')
# Out:
# Text(0, 0.5, 'sin x')

# %%
plt.plot(x, np.sin(x) ,'-g',label = 'sin(x)')
plt.plot(x, np.cos(x) , '.b' , label = 'cos(x)')
plt.axis('equal')
plt.legend()
